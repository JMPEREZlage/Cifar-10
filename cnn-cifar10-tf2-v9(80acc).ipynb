# %% [markdown]
# ![Nuclio logo](https://nuclio.school/wp-content/uploads/2018/12/nucleoDS-newBlack.png)

# %% [markdown]
# ## 1. Librerias & Google Drive
#
# Para empezar carguemos esas librerias que nos hacen falta

# %%
from tensorflow import keras as ks
from matplotlib import pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import numpy as np
import time
import datetime

# %% [markdown]
# Incorporamos la carpeta de Google Drive para poder "guardar" nuestros modelos
#
# 1. Abrir barra lateral de Carpeta
# 2.  Hacer click en carpeta con logo de Google Drive

# %%
# Aquí iria el codigo para conectarse a Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## 2. Arquitectura de red del modelo - Proyecto 0

# %%
model = ks.Sequential()

model.add(ks.layers.Conv2D(64, (3, 3), strides=1, activation='relu',
                           padding='same', input_shape=(32,32,3)))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.Conv2D(64, (3, 3), strides=1, activation='relu',
                           padding='same', input_shape=(32,32,3)))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.Conv2D(64, (3, 3), strides=1, activation='relu',
                           padding='same', input_shape=(32,32,3)))
model.add(ks.layers.BatchNormalization())
model.add(ks.layers.MaxPooling2D((2, 2)))
model.add(ks.layers.Conv2D(64, (3, 3), strides=1, activation='relu',
                           padding='same', input_shape=(32,32,3)))
model.add(ks.layers.Conv2D(64, (3, 3), strides=1, activation='relu',
                           padding='same', input_shape=(32,32,3)))
model.add(ks.layers.Conv2D(64, (3, 3), strides=1, activation='relu',
                           padding='same', input_shape=(32,32,3)))

model.add(ks.layers.MaxPooling2D((2, 2)))


model.add(ks.layers.Flatten())
model.add(ks.layers.Dense(64, activation='relu'))
model.add(ks.layers.Dense(10, activation='softmax'))

# %% [markdown]
# Para revisar un modelo, nos basta con llamar al método **.summary()** del modelo

# %%
model.summary()
# Out:
# Model: "sequential_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_20 (Conv2D)                   │ (None, 32, 32, 64)          │           1,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_9                │ (None, 32, 32, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_21 (Conv2D)                   │ (None, 32, 32, 64)          │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_10               │ (None, 32, 32, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_22 (Conv2D)                   │ (None, 32, 32, 64)          │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_11               │ (None, 32, 32, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_6 (MaxPooling2D)       │ (None, 16, 16, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_23 (Conv2D)                   │ (None, 16, 16, 64)          │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_24 (Conv2D)                   │ (None, 16, 16, 64)          │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_25 (Conv2D)                   │ (None, 16, 16, 64)          │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_7 (MaxPooling2D)       │ (None, 8, 8, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_3 (Flatten)                  │ (None, 4096)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_6 (Dense)                      │ (None, 64)                  │         262,208 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_7 (Dense)                      │ (None, 10)                  │             650 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 450,058 (1.72 MB)
#  Trainable params: 449,674 (1.72 MB)
#  Non-trainable params: 384 (1.50 KB)

# %% [markdown]
# ## 3. Optimizador, función error

# %%
model.compile(optimizer='Adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# ## 4. Preparamos los datos
#
# Cargamos los datos de CIFAR10 de los datasets directamente de las librerias de Keras. Estos ya estan dispuestos en train and test
#
# **Detalle importante:**
# > La red neuronal requiere que los inputs sean números reales, y lo haremos forzando la division de los valores de dentro de las matrices 28x28 (que tienen valoress del 0 al 255) por 255.0 (un real)

# %%
cifar10 = ks.datasets.cifar10

(x_train, y_train), (x_test, y_test) = cifar10.load_data()

x_train_scaled, x_test_scaled = x_train / 255.0, x_test / 255.0

# %%
print("Etiquetas de train:", y_train)


# Convertir los datos en arrays de una dimension (vectores) es una buena mejora en el dataset
y_train = y_train.ravel()
y_test = y_test.ravel()


print("Etiquetas de train (en vector):", y_train)
# Out:
# Etiquetas de train: [[6]
#  [9]
#  [9]
#  ...
#  [9]
#  [1]
#  [1]]
# Etiquetas de train (en vector): [6 9 9 ... 9 1 1]

# %% [markdown]
# Obtenemos un array con todas las labels de CIFAR10

# %%
cifar10_labels = [
'airplane', # id 0
'automobile',
'bird',
'cat',
'deer',
'dog',
'frog',
'horse',
'ship',
'truck'
]

print('Number of labels: %s' % len(cifar10_labels))
# Out:
# Number of labels: 10

# %% [markdown]
# Pintemos una muestra de las imagenes del dataset CIFAR10, a ver si se parece en algo a lo que esperamos.
# Primero, vemos que tipos de datos tengo, después mapeamos esas matrices en una escala de grises utilizando el método **.get_cmap()** de PlotLy con los nueve primeros números del dataset.

# %%
# Pintemos una muestra de las las imagenes del dataset MNIST

print('Train: X=%s, y=%s' % (x_train.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test.shape, y_test.shape))

for i in range(9):

    plt.subplot(330 + 1 + i)
    plt.imshow(x_train[i], cmap=plt.get_cmap('gray'))
    plt.title(cifar10_labels[y_train[i]])

plt.subplots_adjust(hspace = 1)
plt.show()
# Out:
# Train: X=(50000, 32, 32, 3), y=(50000,)
# Test: X=(10000, 32, 32, 3), y=(10000,)

# %% [markdown]
# Como vamos a querer ir haciendo validación a la vez que entrenamos (muy practico)

# %%
x_val_scaled = x_train_scaled[-10000:]
y_val = y_train[-10000:]

x_train_scaled = x_train_scaled[:-10000]
y_train = y_train[:-10000]

# %% [markdown]
# Cuando añadimos convoluciones, necesitamos "pre-tratar los datos", porque **la convolución espera una matriz de 4 campos** (más parecido a "imagenes"), en el caso de MNIST. CIFAR10 ya tiene el shape adecuado, así que no tenemos que hacer nada, pero como siempre decimos: es mejor que comprobeis su tamaño.
#
# Por eso, al salir de la Convolution, hay que hacer un Flatten, porque las capas FullDense esperan arrays, no matrices!!
#
# Luego lo imprimimos para ver que todo está correcto

# %%
# Validamos el resultado
print('Train: X=%s, y=%s' % (x_train_scaled.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test_scaled.shape, y_test.shape))
print('Validation: X=%s, y=%s' % (x_val_scaled.shape, y_val.shape))
# Out:
# Train: X=(40000, 32, 32, 3), y=(40000,)
# Test: X=(10000, 32, 32, 3), y=(10000,)
# Validation: X=(10000, 32, 32, 3), y=(10000,)

# %% [markdown]
# Early stopping:

# %%
from tensorflow.keras.callbacks import EarlyStopping

# %%
callback_earlystopping_accuracy = EarlyStopping(monitor='val_accuracy', patience=7, restore_best_weights=True)
callback_earlystopping_loss = EarlyStopping(monitor='val_loss', patience=7, restore_best_weights=True)

# %%
datagen = ImageDataGenerator(
    rotation_range=20,            # Rotación aleatoria de hasta 20 grados
    width_shift_range=0.2,        # Desplazamiento horizontal aleatorio del 20%
    height_shift_range=0.2,       # Desplazamiento vertical aleatorio del 20%
    shear_range=0.2,             # Distorsión de corte aleatoria del 20%
    zoom_range=0.2,              # Zoom aleatorio del 20%
    horizontal_flip=True,         # Volteo horizontal aleatorio
    fill_mode='nearest'          # Método para rellenar píxeles nuevos
)

# %%
train_generator = datagen.flow(
    x_train_scaled,
    y_train,
    batch_size=512  # Mantén el mismo batch size que antes
)

# %% [markdown]
# ## 5. Entrenamiento
#
# Ya podemos ponernos a entrenar el modelo!! Ojo, que hemos de entrenar contra los datos convertidos al formato que espera la Convolution.
#
# Empezaremos con 30 epocs, es decir, 30 pasadas completas del dataset (que a su vez sera con mini-batches internamente), fijando un batch de 64
#
# El metodo .fit() nos permite, definir además si disponemos de varias CPUs, GPUs, y si queremos ir validando datos a cada fin de epoch.

# %%
t = time.perf_counter()

# %%
history = model.fit(
    train_generator,
    epochs=50,
    validation_data=(x_val_scaled, y_val)
)
# Out:
# Epoch 1/50
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 41s 380ms/step - accuracy: 0.2718 - loss: 1.9932 - val_accuracy: 0.1014 - val_loss: 2.6665
# Epoch 2/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 28s 330ms/step - accuracy: 0.4617 - loss: 1.4854 - val_accuracy: 0.1014 - val_loss: 3.1709
# Epoch 3/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 41s 330ms/step - accuracy: 0.5130 - loss: 1.3398 - val_accuracy: 0.1122 - val_loss: 3.1171
# Epoch 4/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 28s 330ms/step - accuracy: 0.5622 - loss: 1.2214 - val_accuracy: 0.1396 - val_loss: 2.7746
# Epoch 5/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 41s 336ms/step - accuracy: 0.5940 - loss: 1.1273 - val_accuracy: 0.2410 - val_loss: 2.4779
# Epoch 6/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 28s 333ms/step - accuracy: 0.6229 - loss: 1.0602 - val_accuracy: 0.4647 - val_loss: 1.5499
# Epoch 7/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 41s 329ms/step - accuracy: 0.6394 - loss: 1.0031 - val_accuracy: 0.5529 - val_loss: 1.2549
# Epoch 8/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 41s 333ms/step - accuracy: 0.6581 - loss: 0.9584 - val_accuracy: 0.6996 - val_loss: 0.8449
# Epoch 9/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 41s 328ms/step - accuracy: 0.6776 - loss: 0.9137 - val_accuracy: 0.7030 - val_loss: 0.8743
# Epoch 10/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 28s 323ms/step - accuracy: 0.6880 - loss: 0.8829 - val_accuracy: 0.7285 - val_loss: 0.7880
# Epoch 11/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 29s 324ms/step - accuracy: 0.6921 - loss: 0.8727 - val_accuracy: 0.7210 - val_loss: 0.8128
# Epoch 12/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 40s 316ms/step - accuracy: 0.7066 - loss: 0.8370 - val_accuracy: 0.7187 - val_loss: 0.8536
# Epoch 13/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 28s 317ms/step - accuracy: 0.7157 - loss: 0.8069 - val_accuracy: 0.6534 - val_loss: 1.1147
# Epoch 14/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 41s 332ms/step - accuracy: 0.7153 - loss: 0.8064 - val_accuracy: 0.7348 - val_loss: 0.7960
# Epoch 15/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 41s 327ms/step - accuracy: 0.7318 - loss: 0.7681 - val_accuracy: 0.7279 - val_loss: 0.8319
# Epoch 16/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 28s 336ms/step - accuracy: 0.7355 - loss: 0.7485 - val_accuracy: 0.7218 - val_loss: 0.8662
# Epoch 17/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 41s 331ms/step - accuracy: 0.7448 - loss: 0.7334 - val_accuracy: 0.7667 - val_loss: 0.6847
# Epoch 18/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 41s 338ms/step - accuracy: 0.7468 - loss: 0.7310 - val_accuracy: 0.7558 - val_loss: 0.7201
# Epoch 19/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 40s 330ms/step - accuracy: 0.7496 - loss: 0.7158 - val_accuracy: 0.7450 - val_loss: 0.7672
# Epoch 20/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 28s 330ms/step - accuracy: 0.7603 - loss: 0.6887 - val_accuracy: 0.6573 - val_loss: 1.0709
# Epoch 21/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 41s 324ms/step - accuracy: 0.7600 - loss: 0.6882 - val_accuracy: 0.7702 - val_loss: 0.7044
# Epoch 22/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 42s 321ms/step - accuracy: 0.7685 - loss: 0.6629 - val_accuracy: 0.7673 - val_loss: 0.6837
# Epoch 23/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 29s 324ms/step - accuracy: 0.7686 - loss: 0.6684 - val_accuracy: 0.7659 - val_loss: 0.7003
# Epoch 24/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 28s 331ms/step - accuracy: 0.7687 - loss: 0.6677 - val_accuracy: 0.7791 - val_loss: 0.6801
# Epoch 25/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 28s 329ms/step - accuracy: 0.7762 - loss: 0.6392 - val_accuracy: 0.7819 - val_loss: 0.6621
# Epoch 26/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 28s 327ms/step - accuracy: 0.7858 - loss: 0.6163 - val_accuracy: 0.7721 - val_loss: 0.7242
# Epoch 27/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 41s 330ms/step - accuracy: 0.7827 - loss: 0.6197 - val_accuracy: 0.7854 - val_loss: 0.6855
# Epoch 28/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 41s 332ms/step - accuracy: 0.7876 - loss: 0.6026 - val_accuracy: 0.7633 - val_loss: 0.7600
# Epoch 29/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 41s 332ms/step - accuracy: 0.7918 - loss: 0.6016 - val_accuracy: 0.7810 - val_loss: 0.6690
# Epoch 30/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 29s 339ms/step - accuracy: 0.7903 - loss: 0.6047 - val_accuracy: 0.7966 - val_loss: 0.6339
# Epoch 31/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 40s 332ms/step - accuracy: 0.7930 - loss: 0.5883 - val_accuracy: 0.7993 - val_loss: 0.6298
# Epoch 32/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 41s 333ms/step - accuracy: 0.8010 - loss: 0.5642 - val_accuracy: 0.7765 - val_loss: 0.6870
# Epoch 33/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 42s 334ms/step - accuracy: 0.7980 - loss: 0.5830 - val_accuracy: 0.7829 - val_loss: 0.6872
# Epoch 34/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 41s 321ms/step - accuracy: 0.8061 - loss: 0.5599 - val_accuracy: 0.8037 - val_loss: 0.6366
# Epoch 35/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 41s 325ms/step - accuracy: 0.8108 - loss: 0.5532 - val_accuracy: 0.8077 - val_loss: 0.6055
# Epoch 36/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 41s 333ms/step - accuracy: 0.8057 - loss: 0.5594 - val_accuracy: 0.8066 - val_loss: 0.6015
# Epoch 37/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 28s 329ms/step - accuracy: 0.8097 - loss: 0.5479 - val_accuracy: 0.8085 - val_loss: 0.6146
# Epoch 38/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 42s 341ms/step - accuracy: 0.8137 - loss: 0.5385 - val_accuracy: 0.8080 - val_loss: 0.5938
# Epoch 39/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 29s 339ms/step - accuracy: 0.8197 - loss: 0.5251 - val_accuracy: 0.7777 - val_loss: 0.7438
# Epoch 40/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 29s 344ms/step - accuracy: 0.8102 - loss: 0.5470 - val_accuracy: 0.8104 - val_loss: 0.5966
# Epoch 41/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 40s 334ms/step - accuracy: 0.8198 - loss: 0.5251 - val_accuracy: 0.8098 - val_loss: 0.5853
# Epoch 42/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 29s 337ms/step - accuracy: 0.8156 - loss: 0.5242 - val_accuracy: 0.8271 - val_loss: 0.5361
# Epoch 43/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 28s 331ms/step - accuracy: 0.8257 - loss: 0.5027 - val_accuracy: 0.7920 - val_loss: 0.6438
# Epoch 44/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 41s 331ms/step - accuracy: 0.8109 - loss: 0.5402 - val_accuracy: 0.8199 - val_loss: 0.5674
# Epoch 45/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 29s 341ms/step - accuracy: 0.8270 - loss: 0.4991 - val_accuracy: 0.8172 - val_loss: 0.5672
# Epoch 46/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 41s 335ms/step - accuracy: 0.8218 - loss: 0.5151 - val_accuracy: 0.8122 - val_loss: 0.6030
# Epoch 47/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 41s 320ms/step - accuracy: 0.8284 - loss: 0.4992 - val_accuracy: 0.8170 - val_loss: 0.5811
# Epoch 48/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 41s 326ms/step - accuracy: 0.8277 - loss: 0.5004 - val_accuracy: 0.8330 - val_loss: 0.5207
# Epoch 49/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 28s 329ms/step - accuracy: 0.8290 - loss: 0.4940 - val_accuracy: 0.8035 - val_loss: 0.6519
# Epoch 50/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 41s 334ms/step - accuracy: 0.8260 - loss: 0.4948 - val_accuracy: 0.8163 - val_loss: 0.5976

# %%
elapsed_time = datetime.timedelta(seconds=(time.perf_counter() - t))

print('Tiempo de entrenamiento:', elapsed_time)
# Out:
# Tiempo de entrenamiento: 0:29:54.839724

# %% [markdown]
# ## 6. Evaluamos los resultados
#
# Obtengamos una grafica de como el error y la accuracy van evolucionando en cada epoch en los datos de entrenamiento y en la validación

# %%
_, acc = model.evaluate(x_test_scaled, y_test, verbose=0)
print('> %.3f' % (acc * 100.0))
# Out:
# > 80.240

# %%
plt.title('Cross Entropy Loss')
plt.plot(history.history['loss'], color='blue', label='train')
plt.plot(history.history['val_loss'], color='orange', label='val')
plt.legend()
plt.show()

plt.title('Classification Accuracy')
plt.plot(history.history['accuracy'], color='blue', label='train')
plt.plot(history.history['val_accuracy'], color='orange', label='val')
plt.legend()
plt.show()

# %% [markdown]
# El coste podemos ver que es estable y es en el epoch 15 que se fija en un valor. Además la accuracy baila alrededor de 0.10. No se puede decir que sea un modelo muy bueno.
#
# Veamos que tipo de predicciones estoy obteniendo sobre el conjunto de test (vamos a pintar las imagenes y sus clasificaciones)

# %%
predictions = model.predict(x_test_scaled)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step

# %% [markdown]
# Una de las ventajas de Python es que hay montones de funciones y código realizado por terceras personas. Aquí me he fusilado unas bonitas funciones (que he adaptado un poco a mis necesidades) para poder pintar las imagenes, su label (ground truth) y las clasificaciones que hemos realizado.

# %%
def plot_image(i, predictions_array, true_label, img):
  predictions_array, true_label, img = predictions_array, true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary)

  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("{} {:2.0f}% ({})".format(predicted_label,
                                100*np.max(predictions_array),
                                true_label),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
  predictions_array, true_label = predictions_array, true_label[i]
  plt.grid(False)
  plt.xticks(range(10))
  plt.yticks([])
  thisplot = plt.bar(range(10), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label].set_color('blue')

# %% [markdown]
# Dibujamos las primeras imagenes, con las predicciones y sus valores reales (un total de 20 imagenes, para no abusar de vuestros laptops)
#
# Coloreamos las prediciones correctas en azul y los fallos en rojo. Aunque primero he impreso las etiquetas para que tengamos una referencia al grafico.

# %%
i = 0
for l in cifar10_labels:
    print(i, l)
    i += 1

num_rows = 5
num_cols = 4
start = 650
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i+start, predictions[i+start], y_test, x_test)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i+start, predictions[i+start], y_test)
plt.tight_layout()
plt.show()
# Out:
# 0 airplane
# 1 automobile
# 2 bird
# 3 cat
# 4 deer
# 5 dog
# 6 frog
# 7 horse
# 8 ship
# 9 truck

# %% [markdown]
# ## 7. Guardamos el modelo para futuras evaluaciones
#
# Id cambiando los nombres del archivo para ir guardando los diversos proyectos.
# Aquí lo guardamos en "local", pero recordad que lo ideal es que lo guardeis en Google Drive (teneis que montar la unidad, fijar la ruta y allí guardar el modelo .h5)

# %%
ruta_googledrive = "/content/drive/MyDrive/Nuclio/Entregables/CuartoEntregable" # A revisar en vuestra instancia

model.save(ruta_googledrive+'cifar10_base_model.keras')
